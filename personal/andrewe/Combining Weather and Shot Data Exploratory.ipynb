# %%
from datetime import datetime
from datetime import time
from datetime import timedelta

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append('../../')

from pygolfdata.data import shotlink


plt.rcParams["figure.figsize"] = (10,5)
pd.options.display.max_rows = 200

# %%
data_path = '../../../golf_course_project_data'

# %%
weather = pd.read_csv(f'{data_path}/pga_tour_weather_data.csv')
weather.shape
# Out:
# (42102, 14)

# %%
weather[:3]
# Out:
#          Date  Hour   Latitude   Longitude Summary  DegreesFahrenheit  \
# 0  2008-09-18     0  34.143845 -118.174506   Clear              66.65
# 1  2008-09-18     1  34.143845 -118.174506   Clear              66.53
# 2  2008-09-18     2  34.143845 -118.174506   Clear              65.86
#
#    Humidity  Visibility  WindBearing  WindGust  WindSpeed  \
# 0      0.74        9.50         88.0       NaN       4.03
# 1      0.75        9.34        144.0       NaN       4.30
# 2      0.78        8.95        131.0       NaN       3.94
#
#    PrecipitationIntensity PrecipitationType    CourseName
# 0                     0.0               NaN  Annandale GC
# 1                     0.0               NaN  Annandale GC
# 2                     0.0               NaN  Annandale GC

# %%
weather['Hour'].value_counts(dropna=False)
# Out:
# 1     1757
# 11    1755
# 12    1755
# 3     1755
# 4     1755
# 5     1755
# 6     1755
# 7     1755
# 8     1755
# 9     1755
# 10    1755
# 0     1755
# 13    1755
# 14    1755
# 15    1755
# 16    1755
# 22    1754
# 17    1754
# 18    1754
# 19    1754
# 20    1754
# 21    1754
# 23    1754
# 2     1742
# Name: Hour, dtype: int64

# %%
weather = weather[weather['Hour'] != 24]
weather.shape
# Out:
# (42102, 14)

# %%
weather['WeatherDateAndHour'] = pd.to_datetime(weather['Date'] + ' ' + weather['Hour'].astype(str).str.zfill(2))
weather[:3]
# Out:
# ----------------------------------------------------------------
# TypeError                      Traceback (most recent call last)
# ~/miniconda3/envs/anaconda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     302             try:
# --> 303                 values, tz = tslib.datetime_to_datetime64(arg)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                     Traceback (most recent call last)
# <ipython-input-5-dd161cb638e2> in <module>()
# ----> 1 weather['WeatherDateAndHour'] = pd.to_datetime(weather['Date'] + ' ' + weather['Hour'].astype(str).str.zfill(2))
#       2 weather[:3]
#
# ~/miniconda3/envs/anaconda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     371     elif isinstance(arg, ABCSeries):
#     372         from pandas import Series
# --> 373         values = _convert_listlike(arg._values, True, format)
#     374         result = Series(values, index=arg.index, name=arg.name)
#     375     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# ~/miniconda3/envs/anaconda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     305             except (ValueError, TypeError):
# --> 306                 raise e
#     307
#     308     if arg is None:
#
# ~/miniconda3/envs/anaconda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     292                     dayfirst=dayfirst,
#     293                     yearfirst=yearfirst,
# --> 294                     require_iso8601=require_iso8601
#     295                 )
#     296
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/miniconda3/envs/anaconda/lib/python3.6/site-packages/dateutil/parser.py in parse(timestr, parserinfo, **kwargs)
#    1180         return parser(parserinfo).parse(timestr, **kwargs)
#    1181     else:
# -> 1182         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1183
#    1184
#
# ~/miniconda3/envs/anaconda/lib/python3.6/site-packages/dateutil/parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     579                 repl['day'] = monthrange(cyear, cmonth)[1]
#     580
# --> 581         ret = default.replace(**repl)
#     582
#     583         if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23

# %%
shots = shotlink.get_shots_augmented([2017], data_path)
shots = shotlink.prepare_shots(shots)
shots.shape
# Out:
# (1214437, 48)

# %%
shots[:3]
# Out:
#   TourCode TourDescription  Year  TournamentNum  PlayerNum  CourseNum  \
# 0        R        PGA TOUR  2017             10       1810        552
# 1        R        PGA TOUR  2017             10       1810        552
# 2        R        PGA TOUR  2017             10       1810        552
#
#    PermanentTournamentNum PlayerFirstName PlayerLastName  Round  \
# 0                     464            Phil      Mickelson      1
# 1                     464            Phil      Mickelson      1
# 2                     464            Phil      Mickelson      1
#
#           ...               Date LeftRight  StrokesGainedBaseline  \
# 0         ...         2016-10-13         R                 -0.091
# 1         ...         2016-10-13         R                  0.076
# 2         ...         2016-10-13         L                  0.070
#
#    StrokesGainedCategory  RecoveryShot  AMWindSpd  PMWindSpd AMWindDir  \
# 0            Off the Tee            No          C       5-10         C
# 1     Approach the Green            No          C       5-10         C
# 2                Putting            No          C       5-10         C
#
#    PMWindDir     ShotDateAndTime
# 0         DW 2016-10-13 12:41:00
# 1         DW 2016-10-13 12:46:00
# 2         DW 2016-10-13 12:50:00
#
# [3 rows x 48 columns]

# %%
# shots['ShotDateAndTime'] = pd.to_datetime(shots['Date'].astype(str) + ' ' + shots['Time'].astype(str).str.zfill(4), format='%Y-%m-%d %H%M')
# shots[:3]

# %%
# without this, merge_asof gives me 'left keys must be sorted' (right key must be sorted too; I don't both here)
shots.sort_values(by=['ShotDateAndTime'], inplace=True)
weather.sort_values(by=['WeatherDateAndHour'], inplace=True)

# %%
combined = pd.merge_asof(shots, weather, left_on='ShotDateAndTime', right_on='WeatherDateAndHour', 
                         suffixes=['_shots', '_weather'], direction='nearest')
combined['TimeDifference'] = combined['ShotDateAndTime'] - combined['WeatherDateAndHour']
combined[:3]
# Out:
#   TourCode TourDescription  Year  TournamentNum  PlayerNum  CourseNum  \
# 0        R        PGA TOUR  2017             10      27644        552
# 1        R        PGA TOUR  2017             10      24358        552
# 2        R        PGA TOUR  2017             10      25720        552
#
#    PermanentTournamentNum PlayerFirstName PlayerLastName  Round  \
# 0                     464           Brian         Harman      1
# 1                     464          Robert       Garrigus      1
# 2                     464            Chad        Collins      1
#
#        ...       Humidity Visibility  WindBearing  WindGust  WindSpeed  \
# 0      ...           0.87       8.94        248.0       NaN       5.32
# 1      ...           0.87       8.94        248.0       NaN       5.32
# 2      ...           0.87       8.94        248.0       NaN       5.32
#
#    PrecipitationIntensity  PrecipitationType              CourseName_weather  \
# 0                     0.0                NaN  Silverado Resort and Spa North
# 1                     0.0                NaN  Silverado Resort and Spa North
# 2                     0.0                NaN  Silverado Resort and Spa North
#
#    WeatherDateAndHour TimeDifference
# 0 2016-10-13 07:00:00       00:20:00
# 1 2016-10-13 07:00:00       00:20:00
# 2 2016-10-13 07:00:00       00:21:00
#
# [3 rows x 64 columns]

# %%
combined.iloc[0]
# Out:
# TourCode                                                R
# TourDescription                                  PGA TOUR
# Year                                                 2017
# TournamentNum                                          10
# PlayerNum                                           27644
# CourseNum                                             552
# PermanentTournamentNum                                464
# PlayerFirstName                                     Brian
# PlayerLastName                                     Harman
# Round                                                   1
# TournamentName                               Safeway Open
# CourseName_shots           Silverado Resort and Spa North
# Hole                                                   10
# HoleScore                                               4
# ParValue                                                4
# Yardage                                               422
# Shot                                                    1
# ShotType                                                S
# NumStrokes                                              1
# FromLocationScorer                                Tee Box
# FromLocationEnhanced                                  NaN
# ToLocationScorer                            Primary Rough
# ToLocationEnhanced                            Right Rough
# Distance                                             9733
# DistanceToPin                                       15192
# InTheHoleFlag                                           N
# AroundTheGreenFlag                                      N
# FirstPuttFlag                                           N
# DistanceToHoleAfterShot                              5443
# Time                                                  720
# Lie                                                  Good
# Elevation                                            With
# Slope                                               Level
# XCoordinate                                   11,230.4060
# YCoordinate                                    9,321.5500
# ZCoordinate                                       84.0580
# DistanceFromCenter                                    693
# DistanceFromEdge                                      281
# Date_shots                            2016-10-13 00:00:00
# LeftRight                                               R
# StrokesGainedBaseline                              -0.133
# StrokesGainedCategory                         Off the Tee
# RecoveryShot                                           No
# AMWindSpd                                               C
# PMWindSpd                                            5-10
# AMWindDir                                               C
# PMWindDir                                              DW
# ShotDateAndTime                       2016-10-13 07:20:00
# Date_weather                                   2016-10-13
# Hour                                                    7
# Latitude                                          38.3487
# Longitude                                        -122.264
# Summary                                             Clear
# DegreesFahrenheit                                   55.09
# Humidity                                             0.87
# Visibility                                           8.94
# WindBearing                                           248
# WindGust                                              NaN
# WindSpeed                                            5.32
# PrecipitationIntensity                                  0
# PrecipitationType                                     NaN
# CourseName_weather         Silverado Resort and Spa North
# WeatherDateAndHour                    2016-10-13 07:00:00
# TimeDifference                            0 days 00:20:00
# Name: 0, dtype: object

# %%
combined.dtypes
# Out:
# TourCode                          category
# TourDescription                   category
# Year                                uint16
# TournamentNum                       uint16
# PlayerNum                           uint16
# CourseNum                           uint16
# PermanentTournamentNum              uint16
# PlayerFirstName                   category
# PlayerLastName                    category
# Round                                uint8
# TournamentName                    category
# CourseName_shots                  category
# Hole                                 uint8
# HoleScore                          float32
# ParValue                             uint8
# Yardage                             uint16
# Shot                                 uint8
# ShotType                          category
# NumStrokes                           uint8
# FromLocationScorer                category
# FromLocationEnhanced                object
# ToLocationScorer                  category
# ToLocationEnhanced                category
# Distance                            uint16
# DistanceToPin                       uint16
# InTheHoleFlag                     category
# AroundTheGreenFlag                category
# FirstPuttFlag                     category
# DistanceToHoleAfterShot             uint16
# Time                                uint16
# Lie                               category
# Elevation                         category
# Slope                             category
# XCoordinate                         object
# YCoordinate                         object
# ZCoordinate                         object
# DistanceFromCenter                  uint16
# DistanceFromEdge                    uint16
# Date_shots                  datetime64[ns]
# LeftRight                         category
# StrokesGainedBaseline              float32
# StrokesGainedCategory             category
# RecoveryShot                      category
# AMWindSpd                         category
# 13:00:00                26
# 02:17:00                26
# 12:09:00                25
# 11:34:00                25
# 12:10:00                25
# 11:47:00                25
# 12:30:00                25
# 11:32:00                25
# 11:49:00                25
# 12:23:00                25
# 01:14:00                25
# 11:05:00                25
# 12:13:00                25
#                      ...
# 15:34:00                 4
# 08:09:00                 4
# 07:34:00                 4
# 08:20:00                 4
# 07:19:00                 4
# 07:14:00                 4
# 15:38:00                 4
# 07:44:00                 4
# -1 days +20:39:00        4
# 15:44:00                 3
# 16:12:00                 3
# 08:32:00                 3
# 08:01:00                 3
# 15:52:00                 3
# 07:43:00                 3
# 07:11:00                 3
# 07:59:00                 3
# 07:22:00                 3
# 07:49:00                 3
# 15:55:00                 3
# 07:33:00                 3
# -1 days +20:24:00        3
# 15:50:00                 3
# -1 days +20:16:00        3
# 15:56:00                 3
# 08:13:00                 3
# -1 days +20:30:00        3
# -1 days +20:43:00        3
# 07:21:00                 3
# 07:01:00                 3
# 07:50:00                 3
# -1 days +20:42:00        3
# 15:46:00                 3
# 07:20:00                 2
# -1 days +20:44:00        2
# 07:29:00                 2
# 06:45:00                 2
# 15:54:00                 2
# -1 days +20:31:00        2
# -1 days +20:48:00        2
# 06:41:00                 2
# 07:09:00                 2
# -1 days +20:25:00        2
# 07:18:00                 2
# 15:57:00                 2
# 16:00:00                 2
# 15:49:00                 2
# 15:48:00                 2
# 06:51:00                 2
# 15:42:00                 2
# 07:27:00                 2
# 15:47:00                 2
# -1 days +20:52:00        2
# 07:12:00                 2
# 07:39:00                 2
# 16:11:00                 2
# 06:44:00                 2
# 06:46:00                 2
# 07:40:00                 2
# 06:57:00                 2
# -1 days +20:53:00        2
# 07:08:00                 2
# 07:24:00                 2
# -1 days +20:40:00        2
# 15:59:00                 2
# 07:31:00                 2
# 15:53:00                 2
# 07:10:00                 2
# 16:02:00                 1
# -1 days +20:41:00        1
# 16:04:00                 1
# 16:03:00                 1
# 06:54:00                 1
# 07:07:00                 1
# -1 days +20:37:00        1
# 16:10:00                 1
# -1 days +20:47:00        1
# 15:43:00                 1
# 16:07:00                 1
# -1 days +20:36:00        1
# 06:47:00                 1
# 06:53:00                 1
# 16:09:00                 1
# -1 days +20:51:00        1
# 06:58:00                 1
# 08:12:00                 1
# 07:03:00                 1
# 07:13:00                 1
# 06:50:00                 1
# 06:36:00                 1
# 07:00:00                 1
# 06:49:00                 1
# 15:58:00                 1
# -1 days +20:46:00        1
# 07:02:00                 1
# 07:53:00                 1
# 06:52:00                 1
# 06:56:00                 1
# 06:59:00                 1
# 06:35:00                 1
# Name: TimeDifference, Length: 886, dtype: int64

# %%
len(combined) - 1203650   # 1203650 is the time-of-writing within +/- 30m count
# Out:
# 10787

# %%
10787 / len(combined) * 100  # pct of shots that don't have weather data w/i 30m
# Out:
# 0.8882305133983895

# %%
foo = abs(combined['TimeDifference']).value_counts(dropna=False)
foo.index = foo.index / np.timedelta64(1,'m') # convert to total minutes
foo.head(10) # use head instead of slice syntax because slice here actually uses index value?
# Out:
# 16.0    40531
# 10.0    40502
# 21.0    40441
# 29.0    40424
# 20.0    40413
# 15.0    40341
# 1.0     40318
# 9.0     40306
# 19.0    40283
# 26.0    40236
# Name: TimeDifference, dtype: int64

# %%
print(len(foo[foo.index <= 30]))
print(foo[foo.index <= 30])
# Out:
# 31
# 16.0    40531
# 10.0    40502
# 21.0    40441
# 29.0    40424
# 20.0    40413
# 15.0    40341
# 1.0     40318
# 9.0     40306
# 19.0    40283
# 26.0    40236
# 2.0     40225
# 22.0    40149
# 25.0    40091
# 3.0     40053
# 7.0     40034
# 11.0    40028
# 8.0     40016
# 17.0    40010
# 28.0    39974
# 14.0    39964
# 13.0    39946
# 18.0    39914
# 6.0     39909
# 4.0     39898
# 27.0    39887
# 12.0    39858
# 24.0    39775
# 5.0     39774
# 23.0    39705
# 30.0    20593
# 0.0     20052
# Name: TimeDifference, dtype: int64

# %%
sum(foo.index > 30), sum(foo[foo.index > 30])
# Out:
# (777, 10787)

# %%
sum(foo[foo.index <= 30]), sum(foo[foo.index > 30])
# Out:
# (1203650, 10787)

# %%
bar = combined[combined['TimeDifference'] > timedelta(minutes=30)]
bar.shape
# Out:
# (10571, 64)

# %%
bar[:3]
# Out:
#       TourCode TourDescription  Year  TournamentNum  PlayerNum  CourseNum  \
# 96061        R        PGA TOUR  2017             60      30191        733
# 96062        R        PGA TOUR  2017             60      25818        733
# 96063        R        PGA TOUR  2017             60      12510        733
#
#        PermanentTournamentNum PlayerFirstName PlayerLastName  Round  \
# 96061                     457          Julián        Etulain      1
# 96062                     457           Scott         Piercy      1
# 96063                     457            Chad       Campbell      1
#
#            ...       Humidity Visibility  WindBearing  WindGust  WindSpeed  \
# 96061      ...           0.66       7.78         78.0       NaN       7.75
# 96062      ...           0.66       7.78         78.0       NaN       7.75
# 96063      ...           0.66       7.78         78.0       NaN       7.75
#
#        PrecipitationIntensity  PrecipitationType CourseName_weather  \
# 96061                     0.0                NaN                NaN
# 96062                     0.0                NaN                NaN
# 96063                     0.0                NaN                NaN
#
#        WeatherDateAndHour TimeDifference
# 96061 2016-11-10 13:00:00       00:31:00
# 96062 2016-11-10 13:00:00       00:31:00
# 96063 2016-11-10 13:00:00       00:31:00
#
# [3 rows x 64 columns]

# %%
len(bar['TimeDifference'].value_counts(dropna=False))
# Out:
# 777

# %%
sum(bar['TimeDifference'].value_counts(dropna=False))
# Out:
# 10571

# %%
bar.groupby(['TournamentName', 'Year']).size()
# Out:
# TournamentName                                   Year
# OHL Classic at Mayakoba                          2017    3252
# SBS Tournament of Champions                      2017    2294
# Sony Open in Hawaii                              2017    5020
# the Memorial Tournament presented by Nationwide  2017       5
# dtype: int64

# %%
combined[combined['TournamentName'] == 'OHL Classic at Mayakoba']['Year'].value_counts()
# Out:
# 2017    28562
# Name: Year, dtype: int64

# %%
combined[combined['TournamentName'] == 'SBS Tournament of Champions']['Year'].value_counts()
# Out:
# 2017    9063
# Name: Year, dtype: int64

# %%
combined[combined['TournamentName'] == 'Sony Open in Hawaii']['Year'].value_counts()
# Out:
# 2017    30430
# Name: Year, dtype: int64

# %%
combined[combined['TournamentName'] == 'the Memorial Tournament presented by Nationwide']['Year'].value_counts()
# Out:
# 2017    28697
# Name: Year, dtype: int64
